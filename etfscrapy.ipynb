# %%
import pandas as pd
import requests
import io
import re
from bs4 import BeautifulSoup

# %%
url_acwi = 'https://www.ishares.com/us/products/239600/ishares-msci-acwi-etf?qt=ACWI'
req = requests.get(url_acwi)

# %%
soup = BeautifulSoup(req.text, 'html.parser')

# %%
csv_loc = 'https://www.ishares.com/' + soup.find('a', string=re.compile('(?i)detailed holdings'))['href']; csv_loc
# Out:
# 'https://www.ishares.com//us/products/239600/ishares-msci-acwi-etf/1467271812596.ajax?fileType=csv&fileName=ACWI_holdings&dataType=fund'

# %%
data = requests.get(csv_loc)

# %%
cols = '(?i)ticker|name|weight|sector|country'
csv_from = re.search('ticker', data.text, re.IGNORECASE).start()
df = pd.read_csv(io.StringIO(data.text[csv_from:])).filter(regex=cols).dropna()
df
# Out:
#       Ticker                                Name  Weight (%)  \
# 0       MSFT                      MICROSOFT CORP        1.83
# 1       AAPL                           APPLE INC        1.75
# 2       AMZN                      AMAZON COM INC        1.62
# 3       INDA              ISHARES MSCI INDIA ETF        1.02
# 4         FB                FACEBOOK CLASS A INC        0.83
# 5        JPM                 JPMORGAN CHASE & CO        0.81
# 6        JNJ                   JOHNSON & JOHNSON        0.80
# 7       GOOG                ALPHABET INC CLASS C        0.79
# 8      GOOGL                ALPHABET INC CLASS A        0.74
# 9        XOM                    EXXON MOBIL CORP        0.69
# 10       BAC                BANK OF AMERICA CORP        0.65
# 11         V                    VISA INC CLASS A        0.61
# 12       UNH              UNITEDHEALTH GROUP INC        0.59
# 13      NESN                           NESTLE SA        0.59
# 14       700                TENCENT HOLDINGS LTD        0.59
# 15       PFE                          PFIZER INC        0.58
# 16      BRKB      BERKSHIRE HATHAWAY INC CLASS B        0.56
# 17       WFC                         WELLS FARGO        0.53
# 18      INTC              INTEL CORPORATION CORP        0.52
# 19      BABA  ALIBABA GROUP HOLDING ADR REPRESEN        0.51
# 20        VZ          VERIZON COMMUNICATIONS INC        0.51
# 21        PG                    PROCTER & GAMBLE        0.50
# 22         T                            AT&T INC        0.50
# 23      CSCO                   CISCO SYSTEMS INC        0.49
# 24       CVX                        CHEVRON CORP        0.49
# 25        HD                      HOME DEPOT INC        0.48
# 26        BA                              BOEING        0.47
# 27       MRK                      MERCK & CO INC        0.47
# 28      NOVN                         NOVARTIS AG        0.44
# 29    005930             SAMSUNG ELECTRONICS LTD        0.42
# ...      ...                                 ...         ...
# 1421     QAR                             QAR/USD        0.00
# 1422     QAR                             QAR/USD        0.00
# 1423     QAR                             QAR/USD        0.00
# 1424     QAR                             QAR/USD        0.00
# 1425     QAR                             QAR/USD        0.00
# 1426     MYR                             MYR/USD        0.00
# 1427     MYR                             MYR/USD        0.00
# 1428     AED                             AED/USD        0.00
# 1429     AED                             AED/USD        0.00
# 1430     AED                             AED/USD        0.00
# 1431     MYR                             MYR/USD        0.00
# 1432     MYR                             MYR/USD        0.00
